# %%
import ice
import matplotlib.pyplot as plt

# %%
pix367 = ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/MODT367_2020-*",layerName="red")
pix721= ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/MODT721_2020-*",layerName="blue")
pixA= ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/MODA_TRUE_2020-*")
pixT= ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/MODT_TRUE_2020-*")
pixM=ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/VIR_NOAA_M11I2I1_2020-*",layerName="blue")
pixN=ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/VIR_NOAA_TRUE_2020-*")
pixS=ice_olate.isolate(r"/nbhome/Nuzhat.Khan/a68/a68a/VIR_SNPP_TRUE_2020-*")
print('done')
# Out:
# done

# %%
a68a_pixel_areas2020= []
a68a_pixel_areas2020.extend([pix367,pix721,pixA,pixT,pixM,pixN,pixS])

# %%
import pickle

# %%
with open('a68a_pixel_areas2020.pkl', 'wb') as outfile:
    pickle.dump(a68a_pixel_areas2020, outfile, pickle.HIGHEST_PROTOCOL)
    
with open('a68a_pixel_areas2020.pkl', 'rb') as infile:
    result = pickle.load(infile)

# %%
results4 = []
with (open("a68a_pixel_areas2020.pkl", "rb")) as openfile:
    while True:
        try:
            results4.append(pickle.load(openfile))
        except EOFError:
            break

# %%
print('367\n')
ice_olate.iceStats(aea367.values())
# Out:
# 367
#
# MED 0    8483.319785
# dtype: float64
# LOWER 0   -30899.678409
# dtype: float64
# UPPER 0    66848.683807
# dtype: float64
# IQR 0    24437.090554
# dtype: float64

# %%
final = {k: v for k, v in results4[0][0].items() if v >= 40000 and v <= 100000}
print(len(list(final)))
final2 = {k: v for k, v in results4[0][1].items() if v >= 76000 and v <= 100000}
print(len(list(final2)))
final3 = {k: v for k, v in results4[0][2].items() if v >= 25000 and v <= 100000}
print(len(list(final3)))
final4 = {k: v for k, v in results4[0][3].items() if v >= 50000 and v <= 100000}
print(len(list(final4)))
final5 = {k: v for k, v in results4[0][4].items() if v >= 50000 and v <= 100000}
print(len(list(final5)))
final6 = {k: v for k, v in results4[0][5].items() if v <= 100000}
print(len(list(final4)))
final7 = {k: v for k, v in results4[0][6].items() if v >= 25000 and v <= 100000}
print(len(list(final7)))
# Out:
# 163
# 41
# 164
# 144
# 41
# 144
# 181

# %%
check = ice.getdates(final)
y = [j for i,j in check]
x = [i for i,j in check]
check2 = ice.getdates(final2)
y2 = [j for i,j in check2]
x2 = [i for i,j in check2]
check3 = ice.getdates(final3)
y3 = [j for i,j in check3]
x3 = [i for i,j in check3]
check4 = ice.getdates(final4)
y4 = [j for i,j in check4]
x4 = [i for i,j in check4]
check5 = ice.getdates(final5)
y5 = [j for i,j in check5]
x5 = [i for i,j in check5]
check6 = ice.getdates(final6)
y6 = [j for i,j in check6]
x6 = [i for i,j in check6]
check7 = ice.getdates(final7)
y7 = [j for i,j in check7]
x7 = [i for i,j in check7]

# %%
plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x,y,color="red")
plt.title("Pixel Areas of A68a in 2020\n MODIS 367",pad=10)
plt.xlabel("Date (YYYY-MM)",labelpad=10)
plt.ylabel("Area (Pixels)",labelpad=10)
plt.xticks(rotation=45)
plt.subplots_adjust(left=0.1)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x2,y2,c="#0000ff")
plt.title("Pixel Areas of A68a in 2020\n MODIS 721")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x3,y3)
plt.title("Pixel Areas of A68a in 2020\n Aqua MODIS")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x4,y4,c="#29995f")
plt.title("Pixel Areas of A68a in 2020\n Terra MODIS")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x5,y5,c="#00a9bd")
plt.title("Pixel Areas of A68a in 2020\n VIIRS NOAA M11-I2-I1")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x6,y6,c="#bd0075")
plt.title("Pixel Areas of A68a in 2020\n VIIRS NOAA")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x7,y7,c="#bdb700")
plt.title("Pixel Areas of A68a in 2020\n VIIRS SNPP")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
plt.show()

# %%
plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x,y,label="MODIS 367")
plt.legend()
plt.title("Pixel Areas of A68a in 2020\n (Red)")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
#plt.ylim(0, 200000)

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x2,y2,label="MODIS 721")
plt.scatter(x5,y5,label="VIIRS NOAA M11-I2-I1")
plt.legend()
plt.title("Pixel Areas of A68a in 2020\n (Blue)")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
#plt.ylim(0, 200000)


plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x3,y3,label="Aqua MODIS")
plt.scatter(x3,y3,label="Terra MODIS")
plt.scatter(x7,y7,label="VIIRS NOAA")
plt.scatter(x7,y7,label="VIIRS SNPP")
plt.legend()
plt.title("Pixel Areas of A68a in 2020\n (True Color)")
plt.xlabel("Date (YYYY-MM)")
plt.ylabel("Area (Pixels)")
plt.xticks(rotation=45)
#plt.ylim(0, 200000)
# Out:
# (array([18262., 18322., 18383., 18444., 18506., 18567., 18628.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x,y,label="367")
plt.legend()
plt.xticks(rotation=45)
plt.ylim(0, 150000)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x2,y2,label="721")
plt.legend()
plt.xticks(rotation=45)
plt.ylim(0, 200000)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x3,y3,label="AQU")
plt.legend()
plt.xticks(rotation=45)
plt.ylim(0, 200000)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x4,y4,label="TER")
plt.legend()
plt.xticks(rotation=45)
plt.ylim(0, 200000)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x5,y5,label="M1")
plt.legend()
plt.xticks(rotation=45)
plt.ylim(0, 200000)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x6,y6,label="NOAA")
plt.legend()
plt.xticks(rotation=45)
#plt.ylim(3000, 10000)
plt.show()

plt.style.use("seaborn")
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x7,y7,label="SNP")
plt.legend()
plt.xticks(rotation=45)
plt.ylim(0, 200000)
plt.show()
